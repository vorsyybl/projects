# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('mw_90.csv')

# %%
raw.drop(['Unnamed: 0', 'Unnamed: 15', 'Unnamed: 1'], axis=1, inplace=True)
raw.rename(columns={'Game': 'title'}, inplace=True)
raw.drop([0, 1, 5, 6, 8, 9, 11, 12, 13], axis=0, inplace=True)

# %%
top10 = raw.loc[:, ['title', 'Watch time', 'Average viewers', 'Followers gained']].head(10)

# %%
top10.plot.bar(x='title', y='Followers gained')
# Out:
# <AxesSubplot:xlabel='title'>

# %%
top10.set_index('title', inplace=True)
top10.plot.pie(y='Followers gained', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Followers gained'>

# %%
top10.corr()
# Out:
#                   Watch time  Average viewers  Followers gained
# Watch time          1.000000         1.000000          0.943027
# Average viewers     1.000000         1.000000          0.943028
# Followers gained    0.943027         0.943028          1.000000

# %%
top10.describe()
# Out:
#          Watch time  Average viewers  Followers gained
# count  1.000000e+01        10.000000      1.000000e+01
# mean   8.594373e+09     66314.100000      3.730241e+06
# std    6.817274e+09     52602.436252      3.560864e+06
# min    3.031816e+09     23393.000000      2.976330e+05
# 25%    3.549959e+09     27391.250000      1.036537e+06
# 50%    5.918116e+09     45664.000000      2.444554e+06
# 75%    1.203826e+10     92887.250000      4.790775e+06
# max    2.407093e+10    185732.000000      1.089328e+07

# %%
top10.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Grand Theft Auto V to World of Warcraft
# Columns: 3 entries, Watch time to Followers gained
# dtypes: int64(3)
# memory usage: 320.0+ bytes
